# %% [markdown]
# <a href="https://colab.research.google.com/github/kmkolasinski/keras_detection/blob/master/fpn_builder_svhn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip uninstall -y tensorflow
! pip install -q tf-nightly==2.2.0.dev20200315
! pip install -q --extra-index-url=https://test.pypi.org/simple/ tensorflow-model-optimization==0.3.0.dev6
# Out:
# WARNING: Skipping tensorflow as it is not installed.

# %%
pip install --upgrade git+https://github.com/kmkolasinski/keras_detection.git
# Out:
# Collecting git+https://github.com/kmkolasinski/keras_detection.git
#   Cloning https://github.com/kmkolasinski/keras_detection.git to /tmp/pip-req-build-0coylety
#   Running command git clone -q https://github.com/kmkolasinski/keras_detection.git /tmp/pip-req-build-0coylety
# Requirement already satisfied, skipping upgrade: numba==0.48.0 in /usr/local/lib/python3.6/dist-packages (from keras-detection==0.1) (0.48.0)
# Requirement already satisfied, skipping upgrade: numpy==1.16.4 in /usr/local/lib/python3.6/dist-packages (from keras-detection==0.1) (1.16.4)
# Requirement already satisfied, skipping upgrade: tsalib==0.2.1 in /usr/local/lib/python3.6/dist-packages (from keras-detection==0.1) (0.2.1)
# Requirement already satisfied, skipping upgrade: matplotlib>=3.1.* in /usr/local/lib/python3.6/dist-packages (from keras-detection==0.1) (3.2.1)
# Requirement already satisfied, skipping upgrade: image-classifiers==1.0.0 in /usr/local/lib/python3.6/dist-packages (from keras-detection==0.1) (1.0.0)
# Requirement already satisfied, skipping upgrade: tqdm>=4.43.0 in /usr/local/lib/python3.6/dist-packages (from keras-detection==0.1) (4.45.0)
# Requirement already satisfied, skipping upgrade: tensorflow-addons>=0.8.* in /usr/local/lib/python3.6/dist-packages (from keras-detection==0.1) (0.8.3)
# Requirement already satisfied, skipping upgrade: imgaug>=0.4 in /usr/local/lib/python3.6/dist-packages (from keras-detection==0.1) (0.4.0)
# Requirement already satisfied, skipping upgrade: cached_property>=1.5 in /usr/local/lib/python3.6/dist-packages (from keras-detection==0.1) (1.5.1)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/lib/python3.6/dist-packages (from numba==0.48.0->keras-detection==0.1) (46.0.0)
# Requirement already satisfied, skipping upgrade: llvmlite<0.32.0,>=0.31.0dev0 in /usr/local/lib/python3.6/dist-packages (from numba==0.48.0->keras-detection==0.1) (0.31.0)
# Requirement already satisfied, skipping upgrade: sympy in /usr/local/lib/python3.6/dist-packages (from tsalib==0.2.1->keras-detection==0.1) (1.1.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.1.*->keras-detection==0.1) (2.4.6)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.1.*->keras-detection==0.1) (2.8.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.1.*->keras-detection==0.1) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/lib/python3.6/dist-packages (from matplotlib>=3.1.*->keras-detection==0.1) (1.1.0)
# Requirement already satisfied, skipping upgrade: keras-applications<=1.0.8,>=1.0.7 in /usr/local/lib/python3.6/dist-packages (from image-classifiers==1.0.0->keras-detection==0.1) (1.0.8)
# Requirement already satisfied, skipping upgrade: typeguard in /usr/local/lib/python3.6/dist-packages (from tensorflow-addons>=0.8.*->keras-detection==0.1) (2.7.1)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.6/dist-packages (from imgaug>=0.4->keras-detection==0.1) (1.12.0)
# Requirement already satisfied, skipping upgrade: Shapely in /usr/local/lib/python3.6/dist-packages (from imgaug>=0.4->keras-detection==0.1) (1.7.0)
# Requirement already satisfied, skipping upgrade: scikit-image>=0.14.2 in /usr/local/lib/python3.6/dist-packages (from imgaug>=0.4->keras-detection==0.1) (0.16.2)
# Requirement already satisfied, skipping upgrade: imageio in /usr/local/lib/python3.6/dist-packages (from imgaug>=0.4->keras-detection==0.1) (2.4.1)
# Requirement already satisfied, skipping upgrade: Pillow in /usr/local/lib/python3.6/dist-packages (from imgaug>=0.4->keras-detection==0.1) (7.0.0)
# Requirement already satisfied, skipping upgrade: scipy in /usr/local/lib/python3.6/dist-packages (from imgaug>=0.4->keras-detection==0.1) (1.4.1)
# Requirement already satisfied, skipping upgrade: opencv-python in /usr/local/lib/python3.6/dist-packages (from imgaug>=0.4->keras-detection==0.1) (4.1.2.30)
# Requirement already satisfied, skipping upgrade: mpmath>=0.19 in /usr/local/lib/python3.6/dist-packages (from sympy->tsalib==0.2.1->keras-detection==0.1) (1.1.0)
# Requirement already satisfied, skipping upgrade: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications<=1.0.8,>=1.0.7->image-classifiers==1.0.0->keras-detection==0.1) (2.10.0)
# Requirement already satisfied, skipping upgrade: PyWavelets>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.14.2->imgaug>=0.4->keras-detection==0.1) (1.1.1)
# Requirement already satisfied, skipping upgrade: networkx>=2.0 in /usr/local/lib/python3.6/dist-packages (from scikit-image>=0.14.2->imgaug>=0.4->keras-detection==0.1) (2.4)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /usr/local/lib/python3.6/dist-packages (from networkx>=2.0->scikit-image>=0.14.2->imgaug>=0.4->keras-detection==0.1) (4.4.2)
# Building wheels for collected packages: keras-detection
#   Building wheel for keras-detection (setup.py) ... done
#   Created wheel for keras-detection: filename=keras_detection-0.1-cp36-none-any.whl size=62541 sha256=7b97030e5e5c7350371df6032fa4f327c7e623c5a61d988caaa579b5f9d35f76
#   Stored in directory: /tmp/pip-ephem-wheel-cache-mqwu62f7/wheels/9c/23/23/2d3299a84b3beda7addbe5f17af1aa74b0e15fd87214803132
# Successfully built keras-detection
# Installing collected packages: keras-detection
#   Found existing installation: keras-detection 0.1
#     Uninstalling keras-detection-0.1:
#       Successfully uninstalled keras-detection-0.1
# Successfully installed keras-detection-0.1

# %%
# test installation
import keras_detection
import tensorflow as tf
tf.__version__
# Out:
# '2.2.0-dev20200315'

# %% [markdown]
# # Download dataset
# Download nad unpack SVHN dataset to datasets/SVHN/[train|test] folder

# %% [markdown]
# Download RAW data

# %%
# !wget http://ufldl.stanford.edu/housenumbers/train.tar.gz
# !wget http://ufldl.stanford.edu/housenumbers/test.tar.gz
# Out:
# --2020-04-04 08:33:04--  http://ufldl.stanford.edu/housenumbers/train.tar.gz
# Resolving ufldl.stanford.edu (ufldl.stanford.edu)... 171.64.68.10
# Connecting to ufldl.stanford.edu (ufldl.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 404141560 (385M) [application/x-gzip]
# Saving to: ‘train.tar.gz’
#
# train.tar.gz        100%[===================>] 385.42M  69.2MB/s    in 7.0s
#
# 2020-04-04 08:33:11 (55.3 MB/s) - ‘train.tar.gz’ saved [404141560/404141560]
#
# --2020-04-04 08:33:12--  http://ufldl.stanford.edu/housenumbers/test.tar.gz
# Resolving ufldl.stanford.edu (ufldl.stanford.edu)... 171.64.68.10
# Connecting to ufldl.stanford.edu (ufldl.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 276555967 (264M) [application/x-gzip]
# Saving to: ‘test.tar.gz’
#
# test.tar.gz         100%[===================>] 263.74M  52.8MB/s    in 5.9s
#
# 2020-04-04 08:33:18 (44.6 MB/s) - ‘test.tar.gz’ saved [276555967/276555967]

# %%
# !tar -xf train.tar.gz
# !tar -xf test.tar.gz

# %% [markdown]
# # Load dataset
# Prepare and load SVHN dataset as tfrecrods, this will take a while ...

# %%
from keras_detection.datasets.svhn.read_svhm_map import load_dataset

train_raw_dataset, num_train_examples = load_dataset('train')
test_raw_dataset, num_test_examples = load_dataset('test')
# Out:
# Loaded train.pkl dataset from existing pickle file. N=33402
# Loaded test.pkl dataset from existing pickle file. N=13068

# %%
train_raw_dataset
# Out:
# <FlatMapDataset shapes: {features: {image: (None, None, 3)}, labels: {boxes: (None, 4), labels: (None,), weights: (None,)}}, types: {features: {image: tf.uint8}, labels: {boxes: tf.float32, labels: tf.int64, weights: tf.float32}}>

# %%
num_train_examples, num_test_examples
# Out:
# (33402, 13068)

# %%
import matplotlib.pyplot as plt
from PIL import Image
import tensorflow as tf
keras = tf.keras

# %%
# disable tensorflow duplicated logs
from tensorflow.python.platform.tf_logging import _logger
_logger.handlers.pop(0)

# %%
train_raw_dataset
# Out:
# <FlatMapDataset shapes: {features: {image: (None, None, 3)}, labels: {boxes: (None, 4), labels: (None,), weights: (None,)}}, types: {features: {image: tf.uint8}, labels: {boxes: tf.float32, labels: tf.int64, weights: tf.float32}}>

# %% [markdown]
# # Define model input and dataset parametres

# %%
num_classes = 10  # SVHN digits
image_dim = 128
batch_size = 64
num_epochs = -1
num_parallel_calls = tf.data.experimental.AUTOTUNE
num_test_steps = num_test_examples // batch_size

# %%
from keras_detection.datasets.datasets_ops import prepare_dataset

# %%
train_dataset = prepare_dataset(
    dataset=train_raw_dataset, 
    augmentation_fn=None,
    model_image_size=(image_dim, image_dim),
    batch_size=batch_size,
    num_epochs=num_epochs,
    shuffle_buffer_size=1024,
    prefetch_buffer_size=8,
    num_parallel_calls=num_parallel_calls
)

test_dataset = prepare_dataset(
    dataset=test_raw_dataset, 
    augmentation_fn=None,
    model_image_size=(image_dim, image_dim),
    batch_size=batch_size,
    num_epochs=num_epochs,
    shuffle_buffer_size=None,
    prefetch_buffer_size=2,
    num_parallel_calls=num_parallel_calls
)

# %% [markdown]
# # Define model

# %%
import keras_detection.backbones.mobilenetv2_customized as mobilenet
import keras_detection.tasks.standard_tasks as standard_tasks
import keras_detection.models.fpn_builder as fpn_builder
import keras_detection.models.utils as kd_utils
from keras_detection.utils import plotting

# %%
backbone = mobilenet.MobileNetV2Backbone(
    input_shape=[image_dim, image_dim, 3],
    alpha=1.0, min_fm_size=10, weights='imagenet'
)

tasks = [
    # predicts objectnes score for each anchor
    standard_tasks.get_objectness_task(label_smoothing=0.02, obj_class="center_ignore_margin"),
    # predicts [height, with, y, x ] location of the box
    standard_tasks.get_box_shape_task("box_shape"),
    # predicts [num_classes] for each anchor (focal loss is not supported yes)
    standard_tasks.get_multiclass_task(num_classes, fl_gamma=0.0, label_smoothing=0, activation='softmax'),
]
# Out:
# INFO:tensorflow:Loading pre-trained model weights: imagenet
# WARNING:tensorflow:Skipping loading of weights for layer Conv_1 due to mismatch in shape ((1, 1, 320, 320) vs (1280, 320, 1, 1)).
# WARNING:tensorflow:Skipping loading of weights for layer Conv_1_bn due to mismatch in shape ((320,) vs (1280,)).
# WARNING:tensorflow:Skipping loading of weights for layer Conv_1_bn due to mismatch in shape ((320,) vs (1280,)).
# WARNING:tensorflow:Skipping loading of weights for layer Conv_1_bn due to mismatch in shape ((320,) vs (1280,)).
# WARNING:tensorflow:Skipping loading of weights for layer Conv_1_bn due to mismatch in shape ((320,) vs (1280,)).

# %%
builder = fpn_builder.FPNBuilder(backbone = backbone, tasks = tasks)
model = builder.build(batch_size=None)
# Out:
# INFO:tensorflow:Input image: (None, 128, 128, 3)
# INFO:tensorflow:Processing backbone: <keras_detection.backbones.mobilenetv2_customized.MobileNetV2Backbone object at 0x7fee55d742b0>
# INFO:tensorflow:Processing feature maps for tasks: ['objectness', 'box_shape', 'classes']
# INFO:tensorflow: Processing feature map (fm16x16)

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# image (InputLayer)              [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv (TensorFlow [(None, 128, 128, 3) 0           image[0][0]
# __________________________________________________________________________________________________
# mobilenetv2_1.00_128 (Model)    (None, 16, 16, 320)  1566848     tf_op_layer_RealDiv[0][0]
# __________________________________________________________________________________________________
# model (Model)                   (None, 16, 16, 1)    184705      mobilenetv2_1.00_128[1][0]
# __________________________________________________________________________________________________
# model_1 (Model)                 (None, 16, 16, 4)    184900      mobilenetv2_1.00_128[1][0]
# __________________________________________________________________________________________________
# model_2 (Model)                 (None, 16, 16, 11)   185355      mobilenetv2_1.00_128[1][0]
# __________________________________________________________________________________________________
# fm16x16/objectness (Activation) (None, 16, 16, 1)    0           model[1][0]
# __________________________________________________________________________________________________
# fm16x16/box_shape (Activation)  (None, 16, 16, 4)    0           model_1[1][0]
# __________________________________________________________________________________________________
# fm16x16/classes (Softmax)       (None, 16, 16, 11)   0           model_2[1][0]
# ==================================================================================================
# Total params: 2,121,808
# Trainable params: 2,095,056
# Non-trainable params: 26,752
# __________________________________________________________________________________________________

# %% [markdown]
# # Train model

# %%
prepared_train_dataset = train_dataset.map(builder.get_build_training_targets_fn())

# %%
# Check the content of targets
prepared_train_dataset
# Out:
# <MapDataset shapes: ({image: (64, 128, 128, 3)}, {fm16x16/objectness: (64, 16, 16, 2), fm16x16/box_shape: (64, 16, 16, 5), fm16x16/classes: (64, 16, 16, 12)}), types: ({image: tf.float32}, {fm16x16/objectness: tf.float32, fm16x16/box_shape: tf.float32, fm16x16/classes: tf.float32})>

# %% [markdown]
# ## Check targets
# Visualize target boxes, target objectness and other

# %%
features, labels = next(iter(prepared_train_dataset))

# %%
fm = "fm16x16"

targets = [labels[n][..., :-1] for n in builder.get_outputs_names()]
targets = builder.predictions_to_dict(targets, postprocess=True)

idx = 1
target=dict(
    objectness=targets[f'{fm}/objectness'][idx],
    boxes_shape_map=targets[f'{fm}/box_shape'][idx],
    classes_map=targets[f'{fm}/classes'][idx],
)

render = plotting.draw_compares(    
    target=target,
    predicted=None,
    all_targets=True,
    draw_fns=[
        plotting.draw_boxes, 
        plotting.draw_classes_map,
        plotting.draw_objectness_map,
        plotting.draw_classes_max_score_map,
    ],
    image=features['image'][idx] / 255,
    score_threshold=0.2, 
)
render
# Out:
# <PIL.Image.Image image mode=RGB size=1440x360 at 0x7F9AC1879780>

# %% [markdown]
# ## Run training model

# %%
l2_reg_fn = kd_utils.get_l2_loss_fn(l2_reg=1e-5, model=model)
model.add_loss(l2_reg_fn)

# %%
model.losses, l2_reg_fn()
# Out:
# ([<tf.Tensor: shape=(), dtype=float32, numpy=0.1784284>],
#  <tf.Tensor: shape=(), dtype=float32, numpy=0.1784284>)

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.001, beta_2=0.995)
model.compile(optimizer, **builder.get_model_compile_args())
model.fit(prepared_train_dataset, epochs=10, steps_per_epoch=500)
# Out:
# Epoch 1/10
# 500/500 [==============================] - 151s 301ms/step - loss: 0.5604 - fm16x16/objectness_loss: 0.0689 - fm16x16/box_shape_loss: 0.0205 - fm16x16/classes_loss: 0.1145 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1243 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9156 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.6906 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0637 - fm16x16/classes_MulticlassAccuracyMetric: 0.1930
# Epoch 2/10
# 500/500 [==============================] - 151s 302ms/step - loss: 0.3550 - fm16x16/objectness_loss: 0.0244 - fm16x16/box_shape_loss: 0.0150 - fm16x16/classes_loss: 0.0362 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1674 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9476 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8248 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0318 - fm16x16/classes_MulticlassAccuracyMetric: 0.3113
# Epoch 3/10
# 500/500 [==============================] - 150s 301ms/step - loss: 0.3055 - fm16x16/objectness_loss: 0.0210 - fm16x16/box_shape_loss: 0.0141 - fm16x16/classes_loss: 0.0322 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1788 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9546 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8427 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0291 - fm16x16/classes_MulticlassAccuracyMetric: 0.4333
# Epoch 4/10
# 500/500 [==============================] - 150s 301ms/step - loss: 0.2865 - fm16x16/objectness_loss: 0.0219 - fm16x16/box_shape_loss: 0.0140 - fm16x16/classes_loss: 0.0316 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1750 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9530 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8331 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0291 - fm16x16/classes_MulticlassAccuracyMetric: 0.4780
# Epoch 5/10
# 500/500 [==============================] - 151s 301ms/step - loss: 0.2832 - fm16x16/objectness_loss: 0.0222 - fm16x16/box_shape_loss: 0.0141 - fm16x16/classes_loss: 0.0314 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1743 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9517 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8305 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0290 - fm16x16/classes_MulticlassAccuracyMetric: 0.4930
# Epoch 6/10
# 500/500 [==============================] - 150s 300ms/step - loss: 0.2866 - fm16x16/objectness_loss: 0.0224 - fm16x16/box_shape_loss: 0.0142 - fm16x16/classes_loss: 0.0317 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1711 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9516 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8278 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0293 - fm16x16/classes_MulticlassAccuracyMetric: 0.4951
# Epoch 7/10
# 500/500 [==============================] - 151s 301ms/step - loss: 0.2899 - fm16x16/objectness_loss: 0.0224 - fm16x16/box_shape_loss: 0.0141 - fm16x16/classes_loss: 0.0314 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1714 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9508 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8283 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0293 - fm16x16/classes_MulticlassAccuracyMetric: 0.5066
# Epoch 8/10
# 500/500 [==============================] - 151s 302ms/step - loss: 0.2980 - fm16x16/objectness_loss: 0.0229 - fm16x16/box_shape_loss: 0.0142 - fm16x16/classes_loss: 0.0320 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1695 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9495 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8238 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0295 - fm16x16/classes_MulticlassAccuracyMetric: 0.5032
# Epoch 9/10
# 500/500 [==============================] - 151s 301ms/step - loss: 0.3077 - fm16x16/objectness_loss: 0.0226 - fm16x16/box_shape_loss: 0.0144 - fm16x16/classes_loss: 0.0332 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1707 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9499 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8272 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0295 - fm16x16/classes_MulticlassAccuracyMetric: 0.4877
# Epoch 10/10
# 500/500 [==============================] - 151s 302ms/step - loss: 0.3160 - fm16x16/objectness_loss: 0.0231 - fm16x16/box_shape_loss: 0.0144 - fm16x16/classes_loss: 0.0318 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1697 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9486 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8237 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0296 - fm16x16/classes_MulticlassAccuracyMetric: 0.4915

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.0001, beta_2=0.99)
model.compile(optimizer, **builder.get_model_compile_args())
model.fit(prepared_train_dataset, epochs=5, steps_per_epoch=500)
# Out:
# Epoch 1/5
# 500/500 [==============================] - 150s 300ms/step - loss: 0.3099 - fm16x16/objectness_loss: 0.0208 - fm16x16/box_shape_loss: 0.0137 - fm16x16/classes_loss: 0.0297 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1741 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9575 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8412 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0290 - fm16x16/classes_MulticlassAccuracyMetric: 0.5296
# Epoch 2/5
# 500/500 [==============================] - 150s 300ms/step - loss: 0.3074 - fm16x16/objectness_loss: 0.0203 - fm16x16/box_shape_loss: 0.0135 - fm16x16/classes_loss: 0.0291 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1772 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9593 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8455 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0286 - fm16x16/classes_MulticlassAccuracyMetric: 0.5599
# Epoch 3/5
# 500/500 [==============================] - 150s 300ms/step - loss: 0.3078 - fm16x16/objectness_loss: 0.0202 - fm16x16/box_shape_loss: 0.0135 - fm16x16/classes_loss: 0.0290 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1776 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9593 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8451 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0286 - fm16x16/classes_MulticlassAccuracyMetric: 0.5677
# Epoch 4/5
# 500/500 [==============================] - 150s 300ms/step - loss: 0.3089 - fm16x16/objectness_loss: 0.0202 - fm16x16/box_shape_loss: 0.0135 - fm16x16/classes_loss: 0.0290 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1774 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9580 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8451 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0287 - fm16x16/classes_MulticlassAccuracyMetric: 0.5750
# Epoch 5/5
# 500/500 [==============================] - 150s 300ms/step - loss: 0.3103 - fm16x16/objectness_loss: 0.0203 - fm16x16/box_shape_loss: 0.0136 - fm16x16/classes_loss: 0.0291 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1769 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9575 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8439 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0288 - fm16x16/classes_MulticlassAccuracyMetric: 0.5745

# %% [markdown]
# There will be a gap between training metrics and evaluation metrics, which comes from the presence of BatchNorm. There will be also a gap between train and test datasets which signalizes the overfitting.

# %%
builder.evaluate_model(model, test_dataset, num_test_steps)
# Out:
# 204/204 [==============================] - 16s 80ms/step - loss: 0.3278 - fm16x16/objectness_loss: 0.0274 - fm16x16/box_shape_loss: 0.0143 - fm16x16/classes_loss: 0.0314 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1945 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.8473 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.6510 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0192 - fm16x16/classes_MulticlassAccuracyMetric: 0.3988
# [0.32783564925193787,
#  0.027440713718533516,
#  0.014333270490169525,
#  0.031426191329956055,
#  0.19446206092834473,
#  0.8473244309425354,
#  0.6510282754898071,
#  0.019239500164985657,
#  0.39881402254104614]

# %%
builder.evaluate_model(model, train_dataset, num_test_steps)
# Out:
# 204/204 [==============================] - 16s 80ms/step - loss: 0.3252 - fm16x16/objectness_loss: 0.0241 - fm16x16/box_shape_loss: 0.0145 - fm16x16/classes_loss: 0.0305 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1964 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9268 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.7281 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0226 - fm16x16/classes_MulticlassAccuracyMetric: 0.5367
# [0.32521215081214905,
#  0.024058770388364792,
#  0.014496973715722561,
#  0.030547628179192543,
#  0.19644096493721008,
#  0.9268253445625305,
#  0.7280843257904053,
#  0.0225659366697073,
#  0.5366548895835876]

# %%
# !mkdir --parents models

# %%
model.save_weights("models/non-quantized-model.h5")

# %%
model.load_weights("models/non-quantized-model.h5")

# %% [markdown]
# # Test trained model

# %%
builder.evaluate_model(model, test_dataset, num_test_steps)
# Out:
# 204/204 [==============================] - 16s 79ms/step - loss: 0.2022 - fm16x16/objectness_loss: 0.0274 - fm16x16/box_shape_loss: 0.0143 - fm16x16/classes_loss: 0.0314 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1945 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.8473 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.6510 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0192 - fm16x16/classes_MulticlassAccuracyMetric: 0.3988
# [0.20219963788986206,
#  0.027440713718533516,
#  0.014333270490169525,
#  0.031426191329956055,
#  0.19446206092834473,
#  0.8473244309425354,
#  0.6510282754898071,
#  0.019239500164985657,
#  0.39881402254104614]

# %%
prepared_test_dataset = test_dataset.map(builder.get_build_training_targets_fn())
dataset_iterator = iter(prepared_test_dataset)

# %%
features, labels = next(dataset_iterator)
predictions = model.predict(features)
predictions = builder.predictions_to_dict(predictions, postprocess=True)

# %%
builder.get_outputs_names()
# Out:
# ['fm16x16/objectness', 'fm16x16/box_shape', 'fm16x16/classes']

# %%
fm = "fm16x16"
targets = [labels[n][..., :-1] for n in builder.get_outputs_names()]
targets = builder.predictions_to_dict(targets, postprocess=True)

# %%
# select index of image in batch
idx = 8
target=dict(
    objectness=targets[f'{fm}/objectness'][idx],
    boxes_shape_map=targets[f'{fm}/box_shape'][idx],
    classes_map=targets[f'{fm}/classes'][idx],
)

predicted=dict(
    objectness=predictions[f'{fm}/objectness'][idx],
    boxes_shape_map=predictions[f'{fm}/box_shape'][idx],
    classes_map=predictions[f'{fm}/classes'][idx],
)

render = plotting.draw_compares(    
    target=target,
    predicted=predicted,
    draw_fns=[
        plotting.draw_boxes, 
        plotting.draw_classes_map,
        plotting.draw_objectness_map,
        plotting.draw_classes_max_score_map,
    ],
    image=features['image'][idx] / 255,
    score_threshold=0.1,
)
render
# Out:
# <PIL.Image.Image image mode=RGB size=1800x360 at 0x7F040EB65A90>

# %% [markdown]
# # Quantize model
# Convert model to quantized version and initialize its weights with previosuly pretrained model

# %%
quantized_model = builder.build_quantized(
    batch_size=None, 
    non_quantized_model_weights="models/non-quantized-model.h5"
)
# Out:
# INFO:tensorflow:Building quantized model with batch_size = None
# INFO:tensorflow:Input image: (None, 128, 128, 3)
# INFO:tensorflow:Processing backbone: <keras_detection.backbones.mobilenetv2_customized.MobileNetV2Backbone object at 0x7fee55d742b0>
# INFO:tensorflow:Processing feature maps for tasks: ['objectness', 'box_shape', 'classes']
# INFO:tensorflow: Processing feature map (fm16x16)
# INFO:tensorflow:Loading weights of base model: models/non-quantized-model.h5
# INFO:tensorflow:Building graph with quantization enabled
# INFO:tensorflow:Input image: (None, 128, 128, 3)
# INFO:tensorflow:Processing backbone: <keras_detection.backbones.mobilenetv2_customized.MobileNetV2Backbone object at 0x7fee55d742b0>
# INFO:tensorflow:Running quantization for model backbone: mobilenetv2_1.00_128
# INFO:tensorflow:Processing feature maps for tasks: ['objectness', 'box_shape', 'classes']
# INFO:tensorflow: Processing feature map (fm16x16)
# INFO:tensorflow:Running quantization for head: 'fm16x16/objectness'
# INFO:tensorflow:Running quantization for head: 'fm16x16/box_shape'
# INFO:tensorflow:Running quantization for head: 'fm16x16/classes'

# %%
quantized_model.summary()
# Out:
# Model: "model_13"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# image (InputLayer)              [(None, 128, 128, 3) 0
# __________________________________________________________________________________________________
# tf_op_layer_RealDiv_4 (TensorFl [(None, 128, 128, 3) 0           image[0][0]
# __________________________________________________________________________________________________
# mobilenetv2_1.00_128 (Model)    (None, 16, 16, 320)  1581907     tf_op_layer_RealDiv_4[0][0]
# __________________________________________________________________________________________________
# model_9 (Model)                 (None, 16, 16, 1)    184846      mobilenetv2_1.00_128[1][0]
# __________________________________________________________________________________________________
# model_10 (Model)                (None, 16, 16, 4)    185047      mobilenetv2_1.00_128[1][0]
# __________________________________________________________________________________________________
# model_11 (Model)                (None, 16, 16, 11)   185516      mobilenetv2_1.00_128[1][0]
# __________________________________________________________________________________________________
# fm16x16/objectness (Activation) (None, 16, 16, 1)    0           model_9[1][0]
# __________________________________________________________________________________________________
# fm16x16/box_shape (Activation)  (None, 16, 16, 4)    0           model_10[1][0]
# __________________________________________________________________________________________________
# fm16x16/classes (Softmax)       (None, 16, 16, 11)   0           model_11[1][0]
# ==================================================================================================
# Total params: 2,137,316
# Trainable params: 2,095,056
# Non-trainable params: 42,260
# __________________________________________________________________________________________________

# %%
# test metrics after quantization, they should be much worse
builder.evaluate_model(quantized_model, test_dataset, num_test_steps)
# Out:
# 204/204 [==============================] - 35s 174ms/step - loss: 2.6749 - fm16x16/objectness_loss: 0.0318 - fm16x16/box_shape_loss: 0.0246 - fm16x16/classes_loss: 2.3969 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1928 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.8318 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.6157 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0205 - fm16x16/classes_MulticlassAccuracyMetric: 0.0559
# [2.6748971939086914,
#  0.031838927417993546,
#  0.02461167611181736,
#  2.396941661834717,
#  0.19284814596176147,
#  0.8317691683769226,
#  0.6157084703445435,
#  0.020511183887720108,
#  0.05586191639304161]

# %% [markdown]
# # Train quantized model

# %%
prepared_train_dataset = train_dataset.map(builder.get_build_training_targets_fn())

# %%
l2_reg_fn = kd_utils.get_l2_loss_fn(l2_reg=1e-5, model=quantized_model)
quantized_model.add_loss(l2_reg_fn)

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.001, beta_2=0.995)
quantized_model.compile(optimizer, **builder.get_model_compile_args())
quantized_model.fit(prepared_train_dataset, epochs=10, steps_per_epoch=500)
quantized_model.save_weights("models/quantized-model.h5")
# Out:
# Epoch 1/10
# 500/500 [==============================] - 328s 657ms/step - loss: 0.5181 - fm16x16/objectness_loss: 0.0263 - fm16x16/box_shape_loss: 0.0278 - fm16x16/classes_loss: 0.0970 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1693 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9364 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8124 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0300 - fm16x16/classes_MulticlassAccuracyMetric: 0.2868
# Epoch 2/10
# 500/500 [==============================] - 327s 654ms/step - loss: 0.3321 - fm16x16/objectness_loss: 0.0209 - fm16x16/box_shape_loss: 0.0169 - fm16x16/classes_loss: 0.0410 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1785 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9550 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8439 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0286 - fm16x16/classes_MulticlassAccuracyMetric: 0.3393
# Epoch 3/10
# 500/500 [==============================] - 327s 654ms/step - loss: 0.2894 - fm16x16/objectness_loss: 0.0198 - fm16x16/box_shape_loss: 0.0142 - fm16x16/classes_loss: 0.0400 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1815 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9583 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8516 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0282 - fm16x16/classes_MulticlassAccuracyMetric: 0.3625
# Epoch 4/10
# 500/500 [==============================] - 326s 651ms/step - loss: 0.2721 - fm16x16/objectness_loss: 0.0193 - fm16x16/box_shape_loss: 0.0136 - fm16x16/classes_loss: 0.0400 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1835 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9592 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8544 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0279 - fm16x16/classes_MulticlassAccuracyMetric: 0.3972
# Epoch 5/10
# 500/500 [==============================] - 325s 651ms/step - loss: 0.2644 - fm16x16/objectness_loss: 0.0194 - fm16x16/box_shape_loss: 0.0134 - fm16x16/classes_loss: 0.0410 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1826 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9594 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8544 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0279 - fm16x16/classes_MulticlassAccuracyMetric: 0.4001
# Epoch 6/10
# 500/500 [==============================] - 325s 651ms/step - loss: 0.2587 - fm16x16/objectness_loss: 0.0191 - fm16x16/box_shape_loss: 0.0134 - fm16x16/classes_loss: 0.0407 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1850 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9599 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8557 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0279 - fm16x16/classes_MulticlassAccuracyMetric: 0.4241
# Epoch 7/10
# 500/500 [==============================] - 326s 651ms/step - loss: 0.2509 - fm16x16/objectness_loss: 0.0187 - fm16x16/box_shape_loss: 0.0132 - fm16x16/classes_loss: 0.0392 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1866 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9606 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8585 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0277 - fm16x16/classes_MulticlassAccuracyMetric: 0.4453
# Epoch 8/10
# 500/500 [==============================] - 325s 651ms/step - loss: 0.2501 - fm16x16/objectness_loss: 0.0187 - fm16x16/box_shape_loss: 0.0132 - fm16x16/classes_loss: 0.0407 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1863 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9612 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8597 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0278 - fm16x16/classes_MulticlassAccuracyMetric: 0.4357
# Epoch 9/10
# 500/500 [==============================] - 325s 651ms/step - loss: 0.2468 - fm16x16/objectness_loss: 0.0189 - fm16x16/box_shape_loss: 0.0132 - fm16x16/classes_loss: 0.0402 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1869 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9602 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8573 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0276 - fm16x16/classes_MulticlassAccuracyMetric: 0.4370
# Epoch 10/10
# 500/500 [==============================] - 326s 651ms/step - loss: 0.2469 - fm16x16/objectness_loss: 0.0185 - fm16x16/box_shape_loss: 0.0131 - fm16x16/classes_loss: 0.0430 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1873 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9611 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8590 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0275 - fm16x16/classes_MulticlassAccuracyMetric: 0.4177

# %%
quantized_model.load_weights("models/quantized-model.h5")

# %%
optimizer = keras.optimizers.Adam(learning_rate=0.0001, beta_2=0.995)
quantized_model.compile(optimizer, **builder.get_model_compile_args())
quantized_model.fit(prepared_train_dataset, epochs=10, steps_per_epoch=500)
quantized_model.save_weights("models/quantized-model.h5")
# Out:
# Epoch 1/10
# 500/500 [==============================] - 325s 651ms/step - loss: 0.2492 - fm16x16/objectness_loss: 0.0175 - fm16x16/box_shape_loss: 0.0126 - fm16x16/classes_loss: 0.0521 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1900 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9669 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8715 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0271 - fm16x16/classes_MulticlassAccuracyMetric: 0.4955
# Epoch 2/10
# 500/500 [==============================] - 325s 650ms/step - loss: 0.2355 - fm16x16/objectness_loss: 0.0166 - fm16x16/box_shape_loss: 0.0122 - fm16x16/classes_loss: 0.0429 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1925 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9700 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8754 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0267 - fm16x16/classes_MulticlassAccuracyMetric: 0.5313
# Epoch 3/10
# 500/500 [==============================] - 324s 648ms/step - loss: 0.2327 - fm16x16/objectness_loss: 0.0163 - fm16x16/box_shape_loss: 0.0122 - fm16x16/classes_loss: 0.0418 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1935 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9705 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8765 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0265 - fm16x16/classes_MulticlassAccuracyMetric: 0.5349
# Epoch 4/10
# 500/500 [==============================] - 325s 650ms/step - loss: 0.2299 - fm16x16/objectness_loss: 0.0160 - fm16x16/box_shape_loss: 0.0120 - fm16x16/classes_loss: 0.0408 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1932 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9721 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8792 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0265 - fm16x16/classes_MulticlassAccuracyMetric: 0.5384
# Epoch 5/10
# 500/500 [==============================] - 325s 650ms/step - loss: 0.2271 - fm16x16/objectness_loss: 0.0158 - fm16x16/box_shape_loss: 0.0120 - fm16x16/classes_loss: 0.0391 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1940 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9727 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8802 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0264 - fm16x16/classes_MulticlassAccuracyMetric: 0.5408
# Epoch 6/10
# 500/500 [==============================] - 325s 649ms/step - loss: 0.2268 - fm16x16/objectness_loss: 0.0157 - fm16x16/box_shape_loss: 0.0119 - fm16x16/classes_loss: 0.0400 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1941 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9731 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8810 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0264 - fm16x16/classes_MulticlassAccuracyMetric: 0.5468
# Epoch 7/10
# 500/500 [==============================] - 324s 649ms/step - loss: 0.2252 - fm16x16/objectness_loss: 0.0155 - fm16x16/box_shape_loss: 0.0119 - fm16x16/classes_loss: 0.0396 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1962 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9722 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8823 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0263 - fm16x16/classes_MulticlassAccuracyMetric: 0.5542
# Epoch 8/10
# 500/500 [==============================] - 325s 651ms/step - loss: 0.2246 - fm16x16/objectness_loss: 0.0155 - fm16x16/box_shape_loss: 0.0118 - fm16x16/classes_loss: 0.0398 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1975 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9723 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8833 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0263 - fm16x16/classes_MulticlassAccuracyMetric: 0.5585
# Epoch 9/10
# 500/500 [==============================] - 325s 650ms/step - loss: 0.2241 - fm16x16/objectness_loss: 0.0153 - fm16x16/box_shape_loss: 0.0118 - fm16x16/classes_loss: 0.0402 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1979 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9727 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8840 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0262 - fm16x16/classes_MulticlassAccuracyMetric: 0.5636
# Epoch 10/10
# 500/500 [==============================] - 325s 649ms/step - loss: 0.2240 - fm16x16/objectness_loss: 0.0153 - fm16x16/box_shape_loss: 0.0118 - fm16x16/classes_loss: 0.0407 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1981 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9734 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8851 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0263 - fm16x16/classes_MulticlassAccuracyMetric: 0.5660

# %%
quantized_model.load_weights("models/quantized-model.h5")

# %% [markdown]
# ## Evalute quantized model

# %%
builder.evaluate_model(quantized_model, test_dataset, num_test_steps)
# Out:
# 204/204 [==============================] - 37s 180ms/step - loss: 0.1881 - fm16x16/objectness_loss: 0.0200 - fm16x16/box_shape_loss: 0.0124 - fm16x16/classes_loss: 0.0438 - fm16x16/objectness_ObjectnessPrecisionAT20pc: 0.1895 - fm16x16/objectness_ObjectnessRecallAT20pc: 0.9306 - fm16x16/objectness_ObjectnessPositivesMeanScore: 0.8317 - fm16x16/objectness_ObjectnessNegativesMeanScore: 0.0237 - fm16x16/classes_MulticlassAccuracyMetric: 0.4416
# [0.1881173998117447,
#  0.020040404051542282,
#  0.012432479299604893,
#  0.04375215992331505,
#  0.18950694799423218,
#  0.9306004643440247,
#  0.8317399024963379,
#  0.023725498467683792,
#  0.44157207012176514]

# %% [markdown]
# ## Visualize predictions from quanized model

# %%
prepared_test_dataset = test_dataset.map(builder.get_build_training_targets_fn())
dataset_iterator = iter(prepared_test_dataset)

# %%
features, labels = next(dataset_iterator)
predictions = quantized_model.predict(features)
predictions = builder.predictions_to_dict(predictions, postprocess=True)
fm = "fm16x16"
targets = [labels[n][..., :-1] for n in builder.get_outputs_names()]
targets = builder.predictions_to_dict(targets, postprocess=True)

# %%
# select index of image in batch
idx = 10
target=dict(
    objectness=targets[f'{fm}/objectness'][idx],
    boxes_shape_map=targets[f'{fm}/box_shape'][idx],
    classes_map=targets[f'{fm}/classes'][idx],
)

predicted=dict(
    objectness=predictions[f'{fm}/objectness'][idx],
    boxes_shape_map=predictions[f'{fm}/box_shape'][idx],
    classes_map=predictions[f'{fm}/classes'][idx],
)

render = plotting.draw_compares(    
    target=target,
    predicted=predicted,
    draw_fns=[
        plotting.draw_boxes, 
        plotting.draw_classes_map,
        plotting.draw_objectness_map,
        plotting.draw_classes_max_score_map,
    ],
    image=features['image'][idx] / 255,
    score_threshold=0.4,
)
render
# Out:
# <PIL.Image.Image image mode=RGB size=1800x360 at 0x7FEE1809F278>

# %% [markdown]
# # Export model to tflite
# Conversion is done with:
# ```python
#     converter = from_keras_model(model)
#     converter.experimental_new_converter = True
#     converter.experimental_new_quantizer = True
#     converter.optimizations = [tf.lite.Optimize.DEFAULT]
# ```

# %%
# creates two versions of the model:  
#  - models/quantized-model.tflite
#  - models/quantized-model-quantized.tflite (for this representative dataset is used to accumulate stats)

exported_model, tflite_models_paths = builder.convert_to_tflite(
    quantized_model, 
    save_path="models/quantized-model.tflite", 
    export_batch_size = 1,
    raw_dataset = test_raw_dataset,  # representative dataset
    num_dataset_samples = 32, # representative dataset number of samples
    num_test_steps = 16, # number of images used to test output statistics
    merge_feature_maps=True,  # merge FPN feature maps into single tensor of shape [1, num_anchors, num_outputs]
    postprocess_outputs=True,  # apply post processing on head outputs e.g. decode box coordinates to [height, width, y_center, x_center]
    convert_quantized_model=True # use representative dataset to generate integer quantized model 
)
# Out:
# INFO:tensorflow:Preparing dataset for export of quantized model
# INFO:tensorflow:Merging feature maps
# INFO:tensorflow:Export outputs
# INFO:tensorflow:- objectness           - Tensor("objectness/Identity:0", shape=(1, 256), dtype=float32)
# INFO:tensorflow:- box_shape            - Tensor("box_shape/Identity:0", shape=(1, 256, 4), dtype=float32)
# INFO:tensorflow:- classes              - Tensor("classes/Identity:0", shape=(1, 256, 10), dtype=float32)
# INFO:tensorflow:Exporting model
# INFO:tensorflow:Converting model to tflite format
# INFO:tensorflow:Model converted successfully
# INFO:tensorflow:Model converted successfully
# INFO:tensorflow:Testing tflite model for N=1 iterations ..
# INFO:tensorflow:Testing tflite model for N=1 iterations ..
# Input details:
# { 'dtype': <class 'numpy.float32'>,
#   'index': 0,
#   'name': 'image',
#   'quantization': (0.0, 0),
#   'quantization_parameters': { 'quantized_dimension': 0,
#                                'scales': array([], dtype=float32),
#                                'zero_points': array([], dtype=int32)},
#   'shape': array([  1, 128, 128,   3], dtype=int32),
#   'shape_signature': array([  1, 128, 128,   3], dtype=int32),
#   'sparsity_parameters': {}}
# Output details:
# { 'dtype': <class 'numpy.float32'>,
#   'index': 184,
#   'name': 'export/box_shape/output',
#   'quantization': (0.0, 0),
#   'quantization_parameters': { 'quantized_dimension': 0,
#                                'scales': array([], dtype=float32),
#                                'zero_points': array([], dtype=int32)},
#   'shape': array([  1, 256,   4], dtype=int32),
#   'shape_signature': array([  1, 256,   4], dtype=int32),
#   'sparsity_parameters': {}}
# { 'dtype': <class 'numpy.float32'>,
#   'index': 190,
#   'name': 'export/classes/output',
#   'quantization': (0.0, 0),
#   'quantization_parameters': { 'quantized_dimension': 0,
#                                'scales': array([], dtype=float32),
#                                'zero_points': array([], dtype=int32)},
#   'shape': array([  1, 256,  10], dtype=int32),
#   'shape_signature': array([  1, 256,  10], dtype=int32),
#   'sparsity_parameters': {}}
# { 'dtype': <class 'numpy.float32'>,
#   'index': 178,
#   'name': 'export/objectness/output',
#   'quantization': (0.0, 0),
#   'quantization_parameters': { 'quantized_dimension': 0,
#                                'scales': array([], dtype=float32),
#                                'zero_points': array([], dtype=int32)},
#   'shape': array([  1, 256], dtype=int32),
#   'shape_signature': array([  1, 256], dtype=int32),
#   'sparsity_parameters': {}}
# INFO:tensorflow:Test finished in 1.551214 seconds
# INFO:tensorflow:Test finished in 1.551214 seconds
# INFO:tensorflow:Model saved to models/quantized-model.tflite
# INFO:tensorflow:Model saved to models/quantized-model.tflite
# INFO:tensorflow:Converting quantized model
# INFO:tensorflow:Converting quantized model
# INFO:tensorflow:Model converted successfully
# INFO:tensorflow:Model converted successfully
# INFO:tensorflow:Testing tflite model for N=1 iterations ..
# INFO:tensorflow:Testing tflite model for N=1 iterations ..
# Input details:
# { 'dtype': <class 'numpy.float32'>,
#   'index': 0,
#   'name': 'image',
#   'quantization': (0.0, 0),
#   'quantization_parameters': { 'quantized_dimension': 0,
#                                'scales': array([], dtype=float32),
#                                'zero_points': array([], dtype=int32)},
#   'shape': array([  1, 128, 128,   3], dtype=int32),
#   'shape_signature': array([  1, 128, 128,   3], dtype=int32),
#   'sparsity_parameters': {}}
# Output details:
# { 'dtype': <class 'numpy.float32'>,
#   'index': 180,
#   'name': 'export/box_shape/output',
#   'quantization': (0.0, 0),
#   'quantization_parameters': { 'quantized_dimension': 0,
#                                'scales': array([], dtype=float32),
#                                'zero_points': array([], dtype=int32)},
#   'shape': array([  1, 256,   4], dtype=int32),
#   'shape_signature': array([  1, 256,   4], dtype=int32),
#   'sparsity_parameters': {}}
# { 'dtype': <class 'numpy.float32'>,
#   'index': 190,
#   'name': 'export/classes/output',
#   'quantization': (0.0, 0),
#   'quantization_parameters': { 'quantized_dimension': 0,
#                                'scales': array([], dtype=float32),
#                                'zero_points': array([], dtype=int32)},
#   'shape': array([  1, 256,  10], dtype=int32),
#   'shape_signature': array([  1, 256,  10], dtype=int32),
#   'sparsity_parameters': {}}
# { 'dtype': <class 'numpy.float32'>,
#   'index': 170,
#   'name': 'export/objectness/output',
#   'quantization': (0.0, 0),
#   'quantization_parameters': { 'quantized_dimension': 0,
#                                'scales': array([], dtype=float32),
#                                'zero_points': array([], dtype=int32)},
#   'shape': array([  1, 256], dtype=int32),
#   'shape_signature': array([  1, 256], dtype=int32),
#   'sparsity_parameters': {}}
# INFO:tensorflow:Test finished in 1.612783 seconds
# INFO:tensorflow:Test finished in 1.612783 seconds
# INFO:tensorflow:Quantized model saved to models/quantized-model.quantized.tflite
# INFO:tensorflow:Quantized model saved to models/quantized-model.quantized.tflite
# INFO:tensorflow:Testing converted model: quantized-model.tflite
# INFO:tensorflow:Testing converted model: quantized-model.tflite
# INFO:tensorflow:Testing converted model: quantized-model.tflite
# INFO:tensorflow:Testing converted model: quantized-model.tflite
# 100%|██████████| 16/16 [00:28<00:00,  1.80s/it]
# INFO:tensorflow:Measured deviation between keras and tflite model:
# INFO:tensorflow:Measured deviation between keras and tflite model:
# INFO:tensorflow:
#  - export/objectness/output
# 	MAE     =  0.007927
# 	RMSE    =  0.035783
# 	Keras   = N(μ=  0.030039, σ=  0.143009)
# 	tflite  = N(μ=  0.027251, σ=  0.135665)
#  - export/box_shape/output
# 	MAE     =  0.006279
# 	RMSE    =  0.013210
# 	Keras   = N(μ=  0.413126, σ=  0.267102)
# 	tflite  = N(μ=  0.413811, σ=  0.267155)
#  - export/classes/output
# 	MAE     =  0.000658
# 	RMSE    =  0.013667
# 	Keras   = N(μ=  0.000562, σ=  0.012718)
# 	tflite  = N(μ=  0.000589, σ=  0.012788)
# INFO:tensorflow:
#  - export/objectness/output
# 	MAE     =  0.007927
# 	RMSE    =  0.035783
# 	Keras   = N(μ=  0.030039, σ=  0.143009)
# 	tflite  = N(μ=  0.027251, σ=  0.135665)
#  - export/box_shape/output
# 	MAE     =  0.006279
# 	RMSE    =  0.013210
# 	Keras   = N(μ=  0.413126, σ=  0.267102)
# 	tflite  = N(μ=  0.413811, σ=  0.267155)
#  - export/classes/output
# 	MAE     =  0.000658
# 	RMSE    =  0.013667
# 	Keras   = N(μ=  0.000562, σ=  0.012718)
# 	tflite  = N(μ=  0.000589, σ=  0.012788)
# INFO:tensorflow:Testing converted model: quantized-model.quantized.tflite
# INFO:tensorflow:Testing converted model: quantized-model.quantized.tflite
# INFO:tensorflow:Testing converted model: quantized-model.quantized.tflite
# INFO:tensorflow:Testing converted model: quantized-model.quantized.tflite
# 100%|██████████| 16/16 [00:27<00:00,  1.71s/it]
# INFO:tensorflow:Measured deviation between keras and tflite model:
# INFO:tensorflow:Measured deviation between keras and tflite model:
# INFO:tensorflow:
#  - export/objectness/output
# 	MAE     =  0.000759
# 	RMSE    =  0.003540
# 	Keras   = N(μ=  0.030039, σ=  0.143009)
# 	tflite  = N(μ=  0.030201, σ=  0.143635)
#  - export/box_shape/output
# 	MAE     =  0.001983
# 	RMSE    =  0.003444
# 	Keras   = N(μ=  0.413126, σ=  0.267102)
# 	tflite  = N(μ=  0.413075, σ=  0.266314)
#  - export/classes/output
# 	MAE     =  0.000494
# 	RMSE    =  0.011030
# 	Keras   = N(μ=  0.000562, σ=  0.012718)
# 	tflite  = N(μ=  0.000565, σ=  0.013538)
# INFO:tensorflow:
#  - export/objectness/output
# 	MAE     =  0.000759
# 	RMSE    =  0.003540
# 	Keras   = N(μ=  0.030039, σ=  0.143009)
# 	tflite  = N(μ=  0.030201, σ=  0.143635)
#  - export/box_shape/output
# 	MAE     =  0.001983
# 	RMSE    =  0.003444
# 	Keras   = N(μ=  0.413126, σ=  0.267102)
# 	tflite  = N(μ=  0.413075, σ=  0.266314)
#  - export/classes/output
# 	MAE     =  0.000494
# 	RMSE    =  0.011030
# 	Keras   = N(μ=  0.000562, σ=  0.012718)
# 	tflite  = N(μ=  0.000565, σ=  0.013538)

# %%
exported_model, tflite_models_paths
# Out:
# (<tensorflow.python.keras.engine.training.Model at 0x7fed947c2e10>,
#  [PosixPath('models/quantized-model.tflite'),
#   PosixPath('models/quantized-model.quantized.tflite')])

# %% [markdown]
# # Create box-predictor from converted model

# %%
box_detector = builder.as_box_detector("models/quantized-model.h5", is_quantized=True)
# Out:
# INFO:tensorflow:Building quantized model with batch_size = None
# INFO:tensorflow:Building quantized model with batch_size = None
# INFO:tensorflow:Building graph with quantization enabled
# INFO:tensorflow:Building graph with quantization enabled
# INFO:tensorflow:Input image: (None, 128, 128, 3)
# INFO:tensorflow:Input image: (None, 128, 128, 3)
# INFO:tensorflow:Processing backbone: <keras_detection.backbones.mobilenetv2_customized.MobileNetV2Backbone object at 0x7fee55d742b0>
# INFO:tensorflow:Processing backbone: <keras_detection.backbones.mobilenetv2_customized.MobileNetV2Backbone object at 0x7fee55d742b0>
# INFO:tensorflow:Running quantization for model backbone: mobilenetv2_1.00_128
# INFO:tensorflow:Running quantization for model backbone: mobilenetv2_1.00_128
# INFO:tensorflow:Processing feature maps for tasks: ['objectness', 'box_shape', 'classes']
# INFO:tensorflow:Processing feature maps for tasks: ['objectness', 'box_shape', 'classes']
# INFO:tensorflow: Processing feature map (fm16x16)
# INFO:tensorflow: Processing feature map (fm16x16)
# INFO:tensorflow:Running quantization for head: 'fm16x16/objectness'
# INFO:tensorflow:Running quantization for head: 'fm16x16/objectness'
# INFO:tensorflow:Running quantization for head: 'fm16x16/box_shape'
# INFO:tensorflow:Running quantization for head: 'fm16x16/box_shape'
# INFO:tensorflow:Running quantization for head: 'fm16x16/classes'
# INFO:tensorflow:Running quantization for head: 'fm16x16/classes'
# INFO:tensorflow:Merging feature maps
# INFO:tensorflow:Merging feature maps
# INFO:tensorflow:Export outputs
# INFO:tensorflow:Export outputs
# INFO:tensorflow:- objectness           - Tensor("objectness_1/Identity:0", shape=(None, 256), dtype=float32)
# INFO:tensorflow:- objectness           - Tensor("objectness_1/Identity:0", shape=(None, 256), dtype=float32)
# INFO:tensorflow:- box_shape            - Tensor("box_shape_1/Identity:0", shape=(None, 256, 4), dtype=float32)
# INFO:tensorflow:- box_shape            - Tensor("box_shape_1/Identity:0", shape=(None, 256, 4), dtype=float32)
# INFO:tensorflow:- classes              - Tensor("classes_1/Identity:0", shape=(None, 256, 10), dtype=float32)
# INFO:tensorflow:- classes              - Tensor("classes_1/Identity:0", shape=(None, 256, 10), dtype=float32)

# %%
predictions = box_detector.predict(features['image'])
predictions[idx].draw(image=features['image'][idx].numpy(), fontsize=20)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=432x432 at 0x7FED8BD0FDD8>

# %%
# prediction from integer quantized model will take a while on the GPU
tflite_box_detector =  builder.as_box_detector("models/quantized-model.tflite")
predictions = tflite_box_detector.predict(features['image'])
predictions[idx].draw(image=features['image'][idx].numpy(), fontsize=20)
# Out:
# INFO:tensorflow:Building box predictor for TFLite model
# INFO:tensorflow:Building box predictor for TFLite model
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=432x432 at 0x7FED8BCF8CF8>

# %%
# load model converted using representative dataset
tflite_box_detector =  builder.as_box_detector("models/quantized-model.quantized.tflite")
predictions = tflite_box_detector.predict(features['image'])
predictions[idx].draw(image=features['image'][idx].numpy(), fontsize=20)
# Out:
# INFO:tensorflow:Building box predictor for TFLite model
# INFO:tensorflow:Building box predictor for TFLite model
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=432x432 at 0x7FED8BC06E10>
